# %%
import pandas as pd

train = pd.read_parquet('..\\data\\processed\\train_features.parquet')

# %%
# NaN values per column
nan_counts = train.isna().sum()

# print columns with NaN values
print(nan_counts[nan_counts > 0])
# Out:
# Flux_corrected_mean_g       1
# Flux_corrected_mean_u      17
# Flux_corrected_mean_y      16
# Flux_corrected_max_g        1
# Flux_corrected_max_u       17
#                          ...
# shape_plumpness_g           1
# shape_plumpness_y          16
# decay_ratio_u              17
# decay_ratio_g               1
# Z_err                    3043
# Length: 64, dtype: int64
